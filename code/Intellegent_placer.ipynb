# %%
from intelligent_placer_lib import preproc_image as PrImg
import matplotlib.pyplot as plt

# %%
path = '..\\Tests\\test2.jpg'

img = PrImg.read_image(path)

plt.imshow(img)

# %%
processed_img = PrImg.make_mask(img)
plt.imshow(processed_img)

# %%
img_counter = PrImg.contours(img)
plt.imshow(img_counter)
